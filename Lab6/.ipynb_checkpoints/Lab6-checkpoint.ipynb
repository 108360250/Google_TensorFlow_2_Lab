# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import initializers
from preprocessing import parse_aug_fn, parse_fn

# %%
# 將train Data重新分成9:1等分，分別分給train data, valid data
train_split, valid_split = ['train[:90%]', 'train[90%:]']
# 取得訓練數據，並順便讀取data的資訊
train_data, info = tfds.load("cifar10", split=train_split, with_info=True)
# 取得驗證數據
valid_data = tfds.load("cifar10", split=valid_split)
# 取得測試數據
test_data = tfds.load("cifar10", split=tfds.Split.TEST)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE  # 自動調整模式
batch_size = 64  # 批次大小
train_num = int(info.splits['train'].num_examples / 10) * 9  # 訓練資料數量

train_data = train_data.shuffle(train_num)  # 打散資料集
# 載入預處理「 parse_aug_fn」function，cpu數量為自動調整模式
train_data = train_data.map(map_func=parse_aug_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
train_data = train_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# 載入預處理「 parse_fn」function，cpu數量為自動調整模式
valid_data = valid_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
valid_data = valid_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# 載入預處理「 parse_fn」function，cpu數量為自動調整模式
test_data = test_data.map(map_func=parse_fn, num_parallel_calls=AUTOTUNE)
# 設定批次大小並將prefetch模式開啟(暫存空間為自動調整模式)
test_data = test_data.batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(64, 3, activation='relu', kernel_initializer='glorot_uniform')(inputs)
x = layers.MaxPool2D()(x)
x = layers.Conv2D(128, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(256, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(128, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Conv2D(64, 3, activation='relu', kernel_initializer='glorot_uniform')(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10)(x)
# 建立網路模型(將輸入到輸出所有經過的網路層連接起來)
model_1 = keras.Model(inputs, outputs, name='model-1')
model_1.summary()
# Out:
# Model: "model-1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 9, 9, 128)         295040
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 64)          73792
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                200768
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 941,066
# Trainable params: 941,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 儲存訓練記錄檔
logs_dirs = 'lab6-logs'
model_cbk = keras.callbacks.TensorBoard(log_dir='lab6-logs')

# 紀錄每一個batch的Loss值變化
model_dirs = logs_dirs + '/models'
os.makedirs(model_dirs, exist_ok=True)
save_model = tf.keras.callbacks.ModelCheckpoint(model_dirs + '/save.h5', 
                                                monitor='val_catrgorical_accuracy', 
                                                mode='max')

# %%
# 設定訓練使用的優化器、損失函數和指標函數
model_1.compile(keras.optimizers.Adam(), 
                loss=keras.losses.CategoricalCrossentropy(from_logits=True), 
                metrics=[keras.metrics.CategoricalAccuracy()])

# %%
# 訓練網路模型
model_1.fit(train_data,
            epochs=100, 
            validation_data=valid_data,
            callbacks=[model_cbk, save_model])
# Out:
# Epoch 1/100
# 704/704 [==============================] - 27s 21ms/step - loss: 2.0767 - categorical_accuracy: 0.2135 - val_loss: 1.7633 - val_categorical_accuracy: 0.3578
# Epoch 2/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.8742 - categorical_accuracy: 0.3031 - val_loss: 1.5460 - val_categorical_accuracy: 0.4092
# Epoch 3/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.7601 - categorical_accuracy: 0.3535 - val_loss: 1.5131 - val_categorical_accuracy: 0.4548
# Epoch 4/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.6681 - categorical_accuracy: 0.3920 - val_loss: 1.3154 - val_categorical_accuracy: 0.5172
# Epoch 5/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.5925 - categorical_accuracy: 0.4267 - val_loss: 1.2767 - val_categorical_accuracy: 0.5348
# Epoch 6/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.5428 - categorical_accuracy: 0.4484 - val_loss: 1.2332 - val_categorical_accuracy: 0.5758
# Epoch 7/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.4803 - categorical_accuracy: 0.4732 - val_loss: 1.1663 - val_categorical_accuracy: 0.5742
# Epoch 8/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.4453 - categorical_accuracy: 0.4903 - val_loss: 1.1028 - val_categorical_accuracy: 0.6034
# Epoch 9/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.4157 - categorical_accuracy: 0.5012 - val_loss: 1.1715 - val_categorical_accuracy: 0.5876
# Epoch 10/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.3827 - categorical_accuracy: 0.5126 - val_loss: 1.1158 - val_categorical_accuracy: 0.5998
# Epoch 11/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.3455 - categorical_accuracy: 0.5236 - val_loss: 1.0031 - val_categorical_accuracy: 0.6468
# Epoch 12/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.3278 - categorical_accuracy: 0.5370 - val_loss: 1.0152 - val_categorical_accuracy: 0.6364
# Epoch 13/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2939 - categorical_accuracy: 0.5471 - val_loss: 0.9654 - val_categorical_accuracy: 0.6636
# Epoch 14/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2757 - categorical_accuracy: 0.5587 - val_loss: 0.9879 - val_categorical_accuracy: 0.6482
# Epoch 15/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2561 - categorical_accuracy: 0.5608 - val_loss: 0.9713 - val_categorical_accuracy: 0.6574
# Epoch 16/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2448 - categorical_accuracy: 0.5672 - val_loss: 0.9179 - val_categorical_accuracy: 0.6808
# Epoch 17/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2278 - categorical_accuracy: 0.5782 - val_loss: 0.9488 - val_categorical_accuracy: 0.6674
# Epoch 18/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2034 - categorical_accuracy: 0.5859 - val_loss: 0.8635 - val_categorical_accuracy: 0.6882
# Epoch 19/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1886 - categorical_accuracy: 0.5903 - val_loss: 0.8992 - val_categorical_accuracy: 0.6798
# Epoch 20/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1716 - categorical_accuracy: 0.5950 - val_loss: 0.8698 - val_categorical_accuracy: 0.6928
# Epoch 21/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1629 - categorical_accuracy: 0.5998 - val_loss: 0.8429 - val_categorical_accuracy: 0.7002
# Epoch 22/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1469 - categorical_accuracy: 0.6055 - val_loss: 0.8170 - val_categorical_accuracy: 0.7120
# Epoch 23/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1382 - categorical_accuracy: 0.6064 - val_loss: 0.8321 - val_categorical_accuracy: 0.7078
# Epoch 24/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1171 - categorical_accuracy: 0.6149 - val_loss: 0.8173 - val_categorical_accuracy: 0.7146
# Epoch 25/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1084 - categorical_accuracy: 0.6211 - val_loss: 0.8006 - val_categorical_accuracy: 0.7172
# Epoch 26/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1010 - categorical_accuracy: 0.6224 - val_loss: 0.7885 - val_categorical_accuracy: 0.7334
# Epoch 27/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.0842 - categorical_accuracy: 0.6250 - val_loss: 0.8327 - val_categorical_accuracy: 0.7098
# Epoch 28/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.0737 - categorical_accuracy: 0.6330 - val_loss: 0.8290 - val_categorical_accuracy: 0.7232
# Epoch 29/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.0721 - categorical_accuracy: 0.6325 - val_loss: 0.7931 - val_categorical_accuracy: 0.7324
# Epoch 30/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.0613 - categorical_accuracy: 0.6356 - val_loss: 0.7612 - val_categorical_accuracy: 0.7372
# Epoch 31/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0493 - categorical_accuracy: 0.6447 - val_loss: 0.7603 - val_categorical_accuracy: 0.7418
# Epoch 32/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0401 - categorical_accuracy: 0.6463 - val_loss: 0.7640 - val_categorical_accuracy: 0.7348
# Epoch 33/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0275 - categorical_accuracy: 0.6483 - val_loss: 0.7961 - val_categorical_accuracy: 0.7286
# Epoch 34/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.0188 - categorical_accuracy: 0.6562 - val_loss: 0.7443 - val_categorical_accuracy: 0.7432
# Epoch 35/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.0188 - categorical_accuracy: 0.6518 - val_loss: 0.7850 - val_categorical_accuracy: 0.7310
# Epoch 36/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.
100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8151 - categorical_accuracy: 0.7288 - val_loss: 0.6418 - val_categorical_accuracy: 0.7900
# Epoch 88/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8104 - categorical_accuracy: 0.7307 - val_loss: 0.6436 - val_categorical_accuracy: 0.7898
# Epoch 89/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8109 - categorical_accuracy: 0.7300 - val_loss: 0.6603 - val_categorical_accuracy: 0.7880
# Epoch 90/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8028 - categorical_accuracy: 0.7340 - val_loss: 0.6374 - val_categorical_accuracy: 0.7886
# Epoch 91/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8091 - categorical_accuracy: 0.7320 - val_loss: 0.6432 - val_categorical_accuracy: 0.7878
# Epoch 92/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8054 - categorical_accuracy: 0.7301 - val_loss: 0.6479 - val_categorical_accuracy: 0.7874
# Epoch 93/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8099 - categorical_accuracy: 0.7337 - val_loss: 0.6523 - val_categorical_accuracy: 0.7804
# Epoch 94/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8019 - categorical_accuracy: 0.7327 - val_loss: 0.6519 - val_categorical_accuracy: 0.7876
# Epoch 95/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8056 - categorical_accuracy: 0.7303 - val_loss: 0.6592 - val_categorical_accuracy: 0.7814
# Epoch 96/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7949 - categorical_accuracy: 0.7372 - val_loss: 0.6304 - val_categorical_accuracy: 0.7942
# Epoch 97/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8041 - categorical_accuracy: 0.7324 - val_loss: 0.7578 - val_categorical_accuracy: 0.7590
# Epoch 98/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7998 - categorical_accuracy: 0.7355 - val_loss: 0.6471 - val_categorical_accuracy: 0.7916
# Epoch 99/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.7807 - categorical_accuracy: 0.7404 - val_loss: 0.6999 - val_categorical_accuracy: 0.7766
# Epoch 100/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.7925 - categorical_accuracy: 0.7373 - val_loss: 0.6202 - val_categorical_accuracy: 0.7964

# %%
class CustomConv2D(tf.keras.layers.Layer):
    def __init__(self, filters, kernel_size, strides=(1, 1), padding="VALID", **kwargs):
        super(CustomConv2D, self).__init__(**kwargs)
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = (1, *strides, 1)
        self.padding = padding

    def build(self, input_shape):
        kernel_h, kernel_w = self.kernel_size
        input_dim = input_shape[-1]
        # 創建卷積的權重值(weights)
        self.w = self.add_weight(name='kernel', 
                                 shape=(kernel_h, kernel_w, input_dim, self.filters),
                                 initializer='glorot_uniform',  # 設定初始化方法
                                 trainable=True)  # 設定這個權重是否能夠訓練(更動)
        # 創建卷積的偏差值(bias)
        self.b = self.add_weight(name='bias', 
                                 shape=(self.filters,),
                                 initializer='zeros',  # 設定初始化方法
                                 trainable=True)  # 設定這個權重是否能夠訓練(更動)

    def call(self, inputs):
        x = tf.nn.conv2d(inputs, self.w, self.strides, padding=self.padding) # 卷積運算
        x = tf.nn.bias_add(x, self.b)  # 加上偏差值
        x = tf.nn.relu(x)  # 激活函數
        return x

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = CustomConv2D(64, (3, 3))(inputs)
x = layers.MaxPool2D()(x)
x = CustomConv2D(128, (3, 3))(x)
x = CustomConv2D(256, (3, 3))(x)
x = CustomConv2D(128, (3, 3))(x)
x = CustomConv2D(64, (3, 3))(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10)(x)
# 建立網路模型(將輸入到輸出所有經過的網路層連接起來)
model_2 = keras.Model(inputs, outputs, name='model-2')
model_2.summary()
# Out:
# Model: "model-2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# custom_conv2d (CustomConv2D) (None, 30, 30, 64)        1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# custom_conv2d_1 (CustomConv2 (None, 13, 13, 128)       73856
# _________________________________________________________________
# custom_conv2d_2 (CustomConv2 (None, 11, 11, 256)       295168
# _________________________________________________________________
# custom_conv2d_3 (CustomConv2 (None, 9, 9, 128)         295040
# _________________________________________________________________
# custom_conv2d_4 (CustomConv2 (None, 7, 7, 64)          73792
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                200768
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 941,066
# Trainable params: 941,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
class SaveModel(tf.keras.callbacks.Callback):
    def __init__(self, weights_file, monitor='loss', mode='min', save_weights_only=False):
        super(SaveModel, self).__init__()
        self.weights_file = weights_file
        self.monitor = monitor
        self.mode = mode
        self.save_weights_only = save_weights_only
        if mode == 'min':
            self.best = np.Inf
        else:
            self.best = -np.Inf
        
    def save_model(self):
        if self.save_weights_only:
            self.model.save_weights(self.weights_file)
        else:
            self.model.save(self.weights_file)

    def on_epoch_end(self, epoch, logs=None):
        monitor_value = logs.get(self.monitor)
        if self.mode == 'min' and monitor_value < self.best:
            self.save_model()
            self.best = monitor_value
        elif self.mode == 'max' and monitor_value > self.best:
            self.save_model()
            self.best = monitor_value

# %%
# 儲存訓練記錄檔
logs_dirs = 'lab6-logs'
model_cbk = keras.callbacks.TensorBoard(log_dir='lab6-logs')

# 紀錄每一個batch的Loss值變化
model_dirs = logs_dirs + '/models'
os.makedirs(model_dirs, exist_ok=True)
custom_save_model = SaveModel(model_dirs + '/custom_save.h5', 
                              monitor='val_custom_catrgorical_accuracy', 
                              mode='max', 
                              save_weights_only=True)

# %%
def custom_categorical_crossentropy(y_true, y_pred):
    # x = tf.reduce_mean(-tf.reduce_sum(y_true * tf.log(y_pred), reduction_indices=[1]))
    x = tf.nn.softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)
    return x

# %%
class CustomCategoricalAccuracy(tf.keras.metrics.Metric):
    def __init__(self, name='custom_catrgorical_accuracy', **kwargs):
        super(CustomCategoricalAccuracy, self).__init__(name=name, **kwargs)
        # 記錄正確預測的數量
        self.correct = self.add_weight('correct_numbers', initializer='zeros')
        # 記錄全部資料的量數
        self.total = self.add_weight('total_numbers', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        # 輸入答案為One-hot編碼，所以取最大的數值為答案
        y_true = tf.argmax(y_true, axis=-1)
        # 取預測輸出最大的數值為預測結果
        y_pred = tf.argmax(y_pred, axis=-1)
        # 比較預測結果是否正確，正確會返回True(正確)，錯誤會返回False(錯誤)
        values = tf.equal(y_true, y_pred)
        # 轉為浮點數True(正確)=1.0，False(錯誤)=0.0
        values = tf.cast(values, tf.float32)
        # 將values所有數值相加就會等於正確預測的總數
        values_sum = tf.reduce_sum(values)
        # 計算這個Batch的資料數量
        num_values = tf.cast(tf.size(values), tf.float32)
        self.correct.assign_add(values_sum)  # 更新正確預測的總數
        self.total.assign_add(num_values)  # 更新資料量的總數

    def result(self):
        # 計算準確率
        return tf.math.divide_no_nan(self.correct, self.total)

    def reset_states(self):
        # 每一次Epoch結束後會重新初始化變數
        self.correct.assign(0.)
        self.total.assign(0.)

# %%
# 設定訓練使用的優化器、損失函數和指標函數
model_2.compile(keras.optimizers.Adam(), 
           loss=custom_categorical_crossentropy, 
           metrics=[CustomCategoricalAccuracy()])

# 訓練網路模型
model_2.fit(train_data,
            epochs=100, 
            validation_data=valid_data,
            callbacks=[model_cbk, custom_save_model])
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer CustomConv2D has arguments in `__init__` and therefore must override `get_config`.
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer CustomConv2D has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/100
#   6/704 [..............................] - ETA: 57s - loss: 1.6844 - custom_catrgorical_accuracy: 0.3958 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0609s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0102s vs `on_train_batch_end` time: 0.0609s). Check your callbacks.
# 704/704 [==============================] - 14s 20ms/step - loss: 1.7037 - custom_catrgorical_accuracy: 0.3786 - val_loss: 1.3894 - val_custom_catrgorical_accuracy: 0.5076
# Epoch 2/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.6162 - custom_catrgorical_accuracy: 0.4177 - val_loss: 1.3132 - val_custom_catrgorical_accuracy: 0.5228
# Epoch 3/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.5476 - custom_catrgorical_accuracy: 0.4490 - val_loss: 1.2939 - val_custom_catrgorical_accuracy: 0.5384
# Epoch 4/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.4944 - custom_catrgorical_accuracy: 0.4690 - val_loss: 1.1234 - val_custom_catrgorical_accuracy: 0.5982
# Epoch 5/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.4344 - custom_catrgorical_accuracy: 0.4943 - val_loss: 1.0858 - val_custom_catrgorical_accuracy: 0.6108
# Epoch 6/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.4022 - custom_catrgorical_accuracy: 0.5083 - val_loss: 1.0740 - val_custom_catrgorical_accuracy: 0.6248
# Epoch 7/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.3579 - custom_catrgorical_accuracy: 0.5248 - val_loss: 1.0288 - val_custom_catrgorical_accuracy: 0.6380
# Epoch 8/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.3221 - custom_catrgorical_accuracy: 0.5374 - val_loss: 1.0138 - val_custom_catrgorical_accuracy: 0.6396 ETA: 0s - loss: 1.3213 - custom_catrgorical_accuracy:
# Epoch 9/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2932 - custom_catrgorical_accuracy: 0.5508 - val_loss: 0.9918 - val_custom_catrgorical_accuracy: 0.6564
# Epoch 10/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2663 - custom_catrgorical_accuracy: 0.5626 - val_loss: 0.9502 - val_custom_catrgorical_accuracy: 0.6714
# Epoch 11/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2407 - custom_catrgorical_accuracy: 0.5697 - val_loss: 0.9124 - val_custom_catrgorical_accuracy: 0.6774
# Epoch 12/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.2215 - custom_catrgorical_accuracy: 0.5772 - val_loss: 0.9176 - val_custom_catrgorical_accuracy: 0.6690
# Epoch 13/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1981 - custom_catrgorical_accuracy: 0.5849 - val_loss: 0.8731 - val_custom_catrgorical_accuracy: 0.6900
# Epoch 14/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1819 - custom_catrgorical_accuracy: 0.5900 - val_loss: 0.8942 - val_custom_catrgorical_accuracy: 0.6810
# Epoch 15/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1594 - custom_catrgorical_accuracy: 0.5994 - val_loss: 0.8573 - val_custom_catrgorical_accuracy: 0.6942
# Epoch 16/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1506 - custom_catrgorical_accuracy: 0.6032 - val_loss: 0.9071 - val_custom_catrgorical_accuracy: 0.6774
# Epoch 17/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1298 - custom_catrgorical_accuracy: 0.6110 - val_loss: 0.8250 - val_custom_catrgorical_accuracy: 0.7130
# Epoch 18/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1162 - custom_catrgorical_accuracy: 0.6142 - val_loss: 0.8112 - val_custom_catrgorical_accuracy: 0.7182
# Epoch 19/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.1115 - custom_catrgorical_accuracy: 0.6197 - val_loss: 0.7999 - val_custom_catrgorical_accuracy: 0.7226
# Epoch 20/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0892 - custom_catrgorical_accuracy: 0.6258 - val_loss: 0.8035 - val_custom_catrgorical_accuracy: 0.7222
# Epoch 21/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0883 - custom_catrgorical_accuracy: 0.6268 - val_loss: 0.8294 - val_custom_catrgorical_accuracy: 0.7018
# Epoch 22/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0860 - custom_catrgorical_accuracy: 0.6300 - val_loss: 0.7981 - val_custom_catrgorical_accuracy: 0.7118
# Epoch 23/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0592 - custom_catrgorical_accuracy: 0.6390 - val_loss: 0.7877 - val_custom_catrgorical_accuracy: 0.7230
# Epoch 24/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0554 - custom_catrgorical_accuracy: 0.6416 - val_loss: 0.7681 - val_custom_catrgorical_accuracy: 0.7330
# Epoch 25/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0317 - custom_catrgorical_accuracy: 0.6467 - val_loss: 0.7984 - val_custom_catrgorical_accuracy: 0.7312
# Epoch 26/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0283 - custom_catrgorical_accuracy: 0.6502 - val_loss: 0.8495 - val_custom_catrgorical_accuracy: 0.7056
# Epoch 27/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0142 - custom_catrgorical_accuracy: 0.6564 - val_loss: 0.7447 - val_custom_catrgorical_accuracy: 0.7426
# Epoch 28/100
# 704/704 [==============================] - 14s 19ms/step - loss: 1.0053 - custom_catrgorical_accuracy: 0.6583 - val_loss: 0.7071 - val_custom_catrgorical_accuracy: 0.7508
# Epoch 29/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.0021 - custom_catrgorical_accuracy: 0.6627 - val_loss: 0.7398 - val_custom_catrgorical_accuracy: 0.7466
# Epoch 30/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9965 - custom_catrgorical_accuracy: 0.6629 - val_loss: 0.7330 - val_custom_catrgorical_accuracy: 0.7510
# Epoch 31/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.9805 - custom_catrgorical_accuracy: 0.6667 - val_loss: 0.7173 - val_custom_catrgorical_accuracy: 0.7562
# Epoch 32/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9840 - custom_catrgorical_accuracy: 0.6674 - val_loss: 0.7492 - val_custom_catrgorical_accuracy: 0.7396
# Epoch 33/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9709 - custom_catrgorical_accuracy: 0.6710 - val_loss: 0.6946 - val_custom_catrgorical_accuracy: 0.7596
# Epoch 34/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.9719 - custom_catrgorical_accuracy: 0.6693 - val_loss: 0.7431 - val_custom_catrgorical_accuracy: 0.7528
# Epoch 35/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9635 - custom_catrgorical_accuracy: 0.6761 - val_loss: 0.7007 - val_custom_catrgorical_accuracy: 0.7546
# Epoch 36/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9528 - custom_catrgorical_accuracy: 0.6770 - val_loss: 0.7015 - val_custom_catrgorical_accuracy: 0.7614
# Epoch 37/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9540 - custom_catrgorical_accuracy: 0.6785 - val_loss: 0.7016 - val_custom_catrgorical_accuracy: 0.7664
# Epoch 38/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9463 - custom_catrgorical_accuracy: 0.6812 - val_loss: 0.6999 - val_custom_catrgorical_accuracy: 0.7592
# Epoch 39/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9440 - custom_catrgorical_accuracy: 0.6862 - val_loss: 0.6608 - val_custom_catrgorical_accuracy: 0.7718
# Epoch 40/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.9343 - custom_catrgorical_accuracy: 0.6850 - val_loss: 0.7195 - val_custom_catrgorical_accuracy: 0.7526
# Epoch 41/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9241 - custom_catrgorical_accuracy: 0.6884 - val_loss: 0.7141 - val_custom_catrgorical_accuracy: 0.7594
# Epoch 42/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9130 - custom_catrgorical_accuracy: 0.6927 - val_loss: 0.6888 - val_custom_catrgorical_accuracy: 0.7682
# Epoch 43/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.9133 - custom_catrgorical_accuracy: 0.6908 - val_loss: 0.6903 - val_custom_catrgorical_accuracy: 0.7688
# Epoch 44/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9066 - custom_catrgorical_accuracy: 0.6966 - val_loss: 0.6568 - val_custom_catrgorical_accuracy: 0.7792
# Epoch 45/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9030 - custom_catrgorical_accuracy: 0.6952 - val_loss: 0.6699 - val_custom_catrgorical_accuracy: 0.7750
# Epoch 46/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8895 - custom_catrgorical_accuracy: 0.7018 - val_loss: 0.6714 - val_custom_catrgorical_accuracy: 0.7738
# Epoch 47/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8953 - custom_catrgorical_accuracy: 0.7012 - val_loss: 0.7137 - val_custom_catrgorical_accuracy: 0.7546
# Epoch 48/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8853 - custom_catrgorical_accuracy: 0.7014 - val_loss: 0.6890 - val_custom_catrgorical_accuracy: 0.7724
# Epoch 49/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8824 - custom_catrgorical_accuracy: 0.7064 - val_loss: 0.6426 - val_custom_catrgorical_accuracy: 0.7826
# Epoch 50/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8838 - custom_catrgorical_accuracy: 0.7051 - val_loss: 0.6738 - val_custom_catrgorical_accuracy: 0.7738
# Epoch 51/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8756 - custom_catrgorical_accuracy: 0.7065 - val_loss: 0.6519 - val_custom_catrgorical_accuracy: 0.7762
# Epoch 52/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8682 - custom_catrgorical_accuracy: 0.7114 - val_loss: 0.6673 - val_custom_catrgorical_accuracy: 0.7778
# Epoch 53/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8709 - custom_catrgorical_accuracy: 0.7084 - val_loss: 0.7097 - val_custom_catrgorical_accuracy: 0.7628
# Epoch 54/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8615 - custom_catrgorical_accuracy: 0.7113 - val_loss: 0.6834 - val_custom_catrgorical_accuracy: 0.7676
# Epoch 55/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8641 - custom_catrgorical_accuracy: 0.7115 - val_loss: 0.6286 - val_custom_catrgorical_accuracy: 0.7864
# Epoch 56/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8530 - custom_catrgorical_accuracy: 0.7153 - val_loss: 0.6389 - val_custom_catrgorical_accuracy: 0.7856
# Epoch 57/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8522 - custom_catrgorical_accuracy: 0.7137 - val_loss: 0.6360 - val_custom_catrgorical_accuracy: 0.7874
# Epoch 58/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8559 - custom_catrgorical_accuracy: 0.7167 - val_loss: 0.6557 - val_custom_catrgorical_accuracy: 0.7852
# Epoch 59/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8485 - custom_catrgorical_accuracy: 0.7143 - val_loss: 0.6549 - val_custom_catrgorical_accuracy: 0.7786
# Epoch 60/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8471 - custom_catrgorical_accuracy: 0.7183 - val_loss: 0.6189 - val_custom_catrgorical_accuracy: 0.7930
# Epoch 61/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.
100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7863 - custom_catrgorical_accuracy: 0.7391 - val_loss: 0.6328 - val_custom_catrgorical_accuracy: 0.7952
# Epoch 84/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7872 - custom_catrgorical_accuracy: 0.7383 - val_loss: 0.6227 - val_custom_catrgorical_accuracy: 0.7892
# Epoch 85/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7860 - custom_catrgorical_accuracy: 0.7412 - val_loss: 0.6041 - val_custom_catrgorical_accuracy: 0.8024
# Epoch 86/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7906 - custom_catrgorical_accuracy: 0.7378 - val_loss: 0.6687 - val_custom_catrgorical_accuracy: 0.7858
# Epoch 87/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7832 - custom_catrgorical_accuracy: 0.7400 - val_loss: 0.6282 - val_custom_catrgorical_accuracy: 0.7914
# Epoch 88/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7746 - custom_catrgorical_accuracy: 0.7440 - val_loss: 0.6393 - val_custom_catrgorical_accuracy: 0.7882
# Epoch 89/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7799 - custom_catrgorical_accuracy: 0.7410 - val_loss: 0.6052 - val_custom_catrgorical_accuracy: 0.7962
# Epoch 90/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7841 - custom_catrgorical_accuracy: 0.7408 - val_loss: 0.6138 - val_custom_catrgorical_accuracy: 0.7970
# Epoch 91/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7832 - custom_catrgorical_accuracy: 0.7410 - val_loss: 0.6171 - val_custom_catrgorical_accuracy: 0.8002
# Epoch 92/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7819 - custom_catrgorical_accuracy: 0.7409 - val_loss: 0.6155 - val_custom_catrgorical_accuracy: 0.8032
# Epoch 93/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7801 - custom_catrgorical_accuracy: 0.7410 - val_loss: 0.6604 - val_custom_catrgorical_accuracy: 0.7892
# Epoch 94/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7682 - custom_catrgorical_accuracy: 0.7464 - val_loss: 0.5947 - val_custom_catrgorical_accuracy: 0.8080
# Epoch 95/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7829 - custom_catrgorical_accuracy: 0.7418 - val_loss: 0.6458 - val_custom_catrgorical_accuracy: 0.7932
# Epoch 96/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7739 - custom_catrgorical_accuracy: 0.7428 - val_loss: 0.6204 - val_custom_catrgorical_accuracy: 0.8010
# Epoch 97/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7702 - custom_catrgorical_accuracy: 0.7439 - val_loss: 0.6206 - val_custom_catrgorical_accuracy: 0.8028
# Epoch 98/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7636 - custom_catrgorical_accuracy: 0.7456 - val_loss: 0.6052 - val_custom_catrgorical_accuracy: 0.7940
# Epoch 99/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7655 - custom_catrgorical_accuracy: 0.7479 - val_loss: 0.6658 - val_custom_catrgorical_accuracy: 0.7938
# Epoch 100/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7592 - custom_catrgorical_accuracy: 0.7488 - val_loss: 0.5910 - val_custom_catrgorical_accuracy: 0.8090

# %%
model_1.load_weights(model_dirs+'/save.h5')
model_2.load_weights(model_dirs+'/custom_save.h5')

# %%
loss_1, acc_1 = model_1.evaluate(test_data)
loss_2, acc_2 = model_2.evaluate(test_data)
loss = [loss_1, loss_2]  
acc = [acc_1, acc_2]
dict = {"Loss": loss, "Accuracy": acc}
pd.DataFrame(dict)
# Out:
# 157/157 [==============================] - 1s 8ms/step - loss: 0.6514 - categorical_accuracy: 0.7905
# 157/157 [==============================] - 1s 6ms/step - loss: 0.6191 - custom_catrgorical_accuracy: 0.7993
#        Loss  Accuracy
# 0  0.651406    0.7905
# 1  0.619064    0.7993
